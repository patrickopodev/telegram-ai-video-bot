# %%
import os, shutil

# Always work from /content/telegram-ai-video-bot
BASE = '/content/telegram-ai-video-bot'
os.chdir('/content')
shutil.rmtree(os.path.join(BASE, 'telegram-ai-video-bot'), ignore_errors=True)
shutil.rmtree(BASE, ignore_errors=True)

# !git clone https://github.com/patrickopodev/telegram-ai-video-bot.git
# %cd telegram-ai-video-bot
# !pip install -r worker/requirements.txt -q

# %%
import os, shutil
from google.colab import userdata, drive

# Secrets (set in Colab 🔑 panel: SUPABASE_URL, SUPABASE_KEY, HF_TOKEN, GROQ_API_KEY)
os.environ["SUPABASE_URL"] = userdata.get("SUPABASE_URL")
os.environ["SUPABASE_KEY"] = userdata.get("SUPABASE_KEY")
os.environ["HF_TOKEN"] = userdata.get("HF_TOKEN")
os.environ["GROQ_API_KEY"] = userdata.get("GROQ_API_KEY")

# Mount Google Drive
drive.mount('/content/drive', force_remount=True)

# Ensure models dir exists (create if missing)
models_dir = "/content/drive/MyDrive/ai-video-models"
os.makedirs(models_dir, exist_ok=True)
os.environ["MODELS_DIR"] = models_dir
print("Models dir:", os.listdir(models_dir))

# %%
# !python scripts/download_models.py wan-1.3b

# %%
# !python worker/gpu_detect.py

# Auto-picks model for this GPU, runs until session ends
# !python worker/worker.py --provider colab --model auto
